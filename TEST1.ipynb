# %% [markdown]
# # TEST
# [lien vers Basthon]()

# %%
def f(x):
    return x**2

for i in range(11):
    print(i, f(i))
# Out:
# 0 0
# 1 1
# 2 4
# 3 9
# 4 16
# 5 25
# 6 36
# 7 49
# 8 64
# 9 81
# 10 100
